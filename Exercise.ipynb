# %%
from qiskit import QuantumCircuit
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram


qc = QuantumCircuit(4)
qc.h([0,2])
qc.rz(0.01,[0,2])
qc.cx([0,2],[1,3])
qc.cx([0,1],[2,3])
qc.h([0,1])
qc.measure_all()
sampler= Sampler()
job= sampler.run(qc)
job_result = job.result()
# print(job_result.quasi_dists)
counts= [q.binary_probabilities() for q in job_result.quasi_dists]
print(counts)
# mixed_measurements = list(*counts)
counts11={}
counts00={}

counts = counts[0]
for key in counts:
    if(key[:2]) == '00':
        counts00[key] = counts[key]
for key in counts:
    if(key[:2]) == '11':
        counts11[key] = counts[key]
        
print(counts11, counts00)

display(plot_histogram(counts11))
display(plot_histogram(counts00))

qc.draw('mpl')
# Out:
# [{'0000': 0.249975000833322, '0001': 2.49991666778e-05, '0010': 2.49991666778e-05, '0011': 0.249975000833322, '1100': 0.2499999999999998, '1111': 0.2499999999999998}]
# {'1100': 0.2499999999999998, '1111': 0.2499999999999998} {'0000': 0.249975000833322, '0001': 2.49991666778e-05, '0010': 2.49991666778e-05, '0011': 0.249975000833322}
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[4], line 36
#      33 display(plot_histogram(counts11))
#      34 display(plot_histogram(counts00))
# ---> 36 qc.draw('mpl')
#
# File c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\circuit\quantumcircuit.py:3263, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#    3260 # pylint: disable=cyclic-import
#    3261 from qiskit.visualization import circuit_drawer
# -> 3263 return circuit_drawer(
#    3264     self,
#    3265     scale=scale,
#    3266     filename=filename,
#    3267     style=style,
#    3268     output=output,
#    3269     interactive=interactive,
#    3270     plot_barriers=plot_barriers,
#    3271     reverse_bits=reverse_bits,
#    3272     justify=justify,
#    3273     vertical_compression=vertical_compression,
#    3274     idle_wires=idle_wires,
#    3275     with_layout=with_layout,
#    3276     fold=fold,
#    3277     ax=ax,
#    3278     initial_state=initial_state,
#    3279     cregbundle=cregbundle,
#    3280     wire_order=wire_order,
#    3281     expr_len=expr_len,
#    3282 )
#
# File c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:323, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#     308     return _generate_latex_source(
#     309         circuit,
#     310         filename=filename,
#    (...)
#     320         wire_order=complete_wire_order,
#     321     )
#     322 elif output == "mpl":
# --> 323     image = _matplotlib_circuit_drawer(
#     324         circuit,
#     325         scale=scale,
#     326         filename=filename,
#     327         style=style,
#     328         plot_barriers=plot_barriers,
#     329         reverse_bits=reverse_bits,
#     330         justify=justify,
#     331         idle_wires=idle_wires,
#     332         with_layout=with_layout,
#     333         fold=fold,
#     334         ax=ax,
#     335         initial_state=initial_state,
#     336         cregbundle=cregbundle,
#     337         wire_order=complete_wire_order,
#     338         expr_len=expr_len,
#     339     )
#     340 else:
#     341     raise VisualizationError(
#     342         "Invalid output type %s selected. The only valid choices "
#     343         "are text, latex, latex_source, and mpl" % output
#     344     )
#
# File c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:703, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#     700 if fold is None:
#     701     fold = 25
# --> 703 qcd = _matplotlib.MatplotlibDrawer(
#     704     qubits,
#     705     clbits,
#     706     nodes,
#     707     circuit,
#     708     scale=scale,
#     709     style=style,
#     710     reverse_bits=reverse_bits,
#     711     plot_barriers=plot_barriers,
#     712     fold=fold,
#     713     ax=ax,
#     714     initial_state=initial_state,
#     715     cregbundle=cregbundle,
#     716     with_layout=with_layout,
#     717     expr_len=expr_len,
#     718 )
#     719 return qcd.draw(filename)
#
# File c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\utils\classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\utils\lazy_tester.py:41, in _RequireNow.__call__(self, *_args, **_kwargs)
#      40 def __call__(self, *_args, **_kwargs):
# ---> 41     self._tester.require_now(self._feature)
#
# File c:\Users\manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit\utils\lazy_tester.py:221, in LazyDependencyManager.require_now(self, feature)
#     219 if self:
#     220     return
# --> 221 raise MissingOptionalLibraryError(
#     222     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     223 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."
